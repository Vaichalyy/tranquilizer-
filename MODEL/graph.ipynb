# %%
import matplotlib.pyplot as plt
import numpy as np
import pytest

series = []
#read the previous posture status to display the graph
file = open('state_values.txt', 'r') 
while file.readline() != "":
    try:
        series.append(int(file.readline()))
    except:
        pass
file.close()
# calculate read status array list length for adjusting x axis
length = len(series) 
def graphVisualization(x, y):
    x_axis = np.array(range(x))
    y_axis = np.array(y)

    plt.plot(x_axis, y_axis)
    plt.title('Anxiety detection')
    plt.xlabel('seconds')
    plt.ylabel('state\n0 - Anxious, 1 - Neutral')
    return plt.show()
graphVisualization(length, series)
    

def test_graphVisualization():
    x = np.array(range(5))
    y = np.array([0,1])
    plt.plot(x, y)
    assert graphVisualization(x, y) == plt.show()
test_graphVisualization()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 33
#      31     plt.plot(x, y)
#      32     assert graphVisualization(x, y) == plt.show()
# ---> 33 test_graphVisualization()
#
# Cell In[1], line 31, in test_graphVisualization()
#      29 x = np.array(range(5))
#      30 y = np.array([0,1])
# ---> 31 plt.plot(x, y)
#      32 assert graphVisualization(x, y) == plt.show()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# ...
